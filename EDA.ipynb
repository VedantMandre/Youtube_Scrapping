# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('MKBHDYoutube_dataset.csv')

# %%
df.head()
# Out:
#                                        Title        Published_date    Views  \
# 0          It's a Normal Smartwatch Until...  2023-03-20T18:03:22Z   160710
# 1        Desk Tour & Daily Tech Update 2023!  2023-03-16T19:45:29Z  1643246
# 2   What is Happening with Samsung's Camera?  2023-03-13T19:26:48Z  2645555
# 3  The Yellow iPhone 14: Love it or Hate it?  2023-03-09T17:43:16Z  1912716
# 4                This Feature is Underrated!  2023-03-05T16:20:33Z  2245846
#
#     Likes  Comments
# 0   19267       346
# 1   67821      2274
# 2  143144      6904
# 3  131903      2270
# 4  164597      1571

# %%
df.isna().any()
# Out:
# Title             False
# Published_date    False
# Views             False
# Likes             False
# Comments          False
# dtype: bool

# %%
# Select the columns you want to include in the pairplot
cols = ['Views', 'Likes', 'Comments']

# Create the pairplot
sns.pairplot(df[cols])

# Show the plot
plt.show()

# %%
# Calculate the correlation matrix
corr_matrix = df.corr()

# Create the heatmap
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot: >

# %%
# Create the histogram for likes
sns.histplot(data=df, x='Likes', bins=20)
# Out:
# <AxesSubplot: xlabel='Likes', ylabel='Count'>

# %%
# Create the scatterplot
sns.scatterplot(data=df, x='Likes', y='Views')
# Out:
# <AxesSubplot: xlabel='Likes', ylabel='Views'>

# %%
top_10_videos = df.sort_values('Views', ascending=False).head(10)

# Create a new column to store the shortened video titles
top_10_videos['Short Title'] = top_10_videos['Title'].apply(lambda x: x[:0])

sns.barplot(data=top_10_videos, x=top_10_videos.index, y='Views')
plt.xticks(ticks=range(10), labels=top_10_videos['Short Title'])
plt.xlabel('Top 10 Videos')
plt.ylabel('Views')
plt.title('Top 10 Videos by Views')
plt.show()
